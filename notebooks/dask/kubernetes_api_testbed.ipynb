# %%
from kubernetes import client, config
import json

# %%
config.load_incluster_config()

# %%
v1  = client.CoreV1Api()

# %% [markdown]
# ## list pods in namespace

# %%
pods = v1.list_namespaced_pod('kubeflow-user')
for pod in pods.items:
    print(
        f'pod name: {pod.metadata.name}, host: {pod.status.host_ip}'
    )
# Out:
# pod name: ml-pipeline-visualizationserver-6b44c6759f-6zb5g, host: 172.18.0.2
# pod name: ml-pipeline-ui-artifact-5dd95d555b-hmgxz, host: 172.18.0.3
# pod name: dask-notebook-0, host: 172.18.0.3
# pod name: dask-scheduler-5697c7dfbb-s8rng, host: 172.18.0.2
# pod name: dask-workers-9d5f6bf45-xs4p9, host: 172.18.0.2
# pod name: dask-workers-9d5f6bf45-5mj8v, host: 172.18.0.2
# pod name: dask-workers-9d5f6bf45-jndm6, host: 172.18.0.3

# %%
pods = v1.list_namespaced_pod('kubeflow')
for pod in pods.items:
    print(
        f'pod name: {pod.metadata.name}, host: {pod.status.host_ip}'
    )
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# /tmp/ipykernel_1943/2485397222.py in <module>
# ----> 1 pods = v1.list_namespaced_pod('kubeflow')
#       2 for pod in pods.items:
#       3     print(
#       4         f'pod name: {pod.metadata.name}, host: {pod.status.host_ip}'
#       5     )
#
# /opt/conda/lib/python3.9/site-packages/kubernetes/client/api/core_v1_api.py in list_namespaced_pod(self, namespace, **kwargs)
#   15421         """
#   15422         kwargs['_return_http_data_only'] = True
# > 15423         return self.list_namespaced_pod_with_http_info(namespace, **kwargs)  # noqa: E501
#   15424
#   15425     def list_namespaced_pod_with_http_info(self, namespace, **kwargs):  # noqa: E501
#
# /opt/conda/lib/python3.9/site-packages/kubernetes/client/api/core_v1_api.py in list_namespaced_pod_with_http_info(self, namespace, **kwargs)
#   15536         auth_settings = ['BearerToken']  # noqa: E501
#   15537
# > 15538         return self.api_client.call_api(
#   15539             '/api/v1/namespaces/{namespace}/pods', 'GET',
#   15540             path_params,
#
# /opt/conda/lib/python3.9/site-packages/kubernetes/client/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     346         """
#     347         if not async_req:
# --> 348             return self.__call_api(resource_path, method,
#     349                                    path_params, query_params, header_params,
#     350                                    body, post_params, files,
#
# /opt/conda/lib/python3.9/site-packages/kubernetes/client/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     178
#     179         # perform request and return response
# --> 180         response_data = self.request(
#     181             method, url, query_params=query_params, headers=header_params,
#     182             post_params=post_params, body=body,
#
# /opt/conda/lib/python3.9/site-packages/kubernetes/client/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     371         """Makes the HTTP request using RESTClient."""
#     372         if method == "GET":
# --> 373             return self.rest_client.GET(url,
#     374                                         query_params=query_params,
#     375                                         _preload_content=_preload_content,
#
# /opt/conda/lib/python3.9/site-packages/kubernetes/client/rest.py in GET(self, url, headers, query_params, _preload_content, _request_timeout)
#     238     def GET(self, url, headers=None, query_params=None, _preload_content=True,
#     239             _request_timeout=None):
# --> 240         return self.request("GET", url,
#     241                             headers=headers,
#     242                             _preload_content=_preload_content,
#
# /opt/conda/lib/python3.9/site-packages/kubernetes/client/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     232
#     233         if not 200 <= r.status <= 299:
# --> 234             raise ApiException(http_resp=r)
#     235
#     236         return r
#
# ApiException: (403)
# Reason: Forbidden
# HTTP response headers: HTTPHeaderDict({'Cache-Control': 'no-cache, private', 'Content-Type': 'application/json', 'X-Content-Type-Options': 'nosniff', 'X-Kubernetes-Pf-Flowschema-Uid': '442b70d5-9891-44ea-a477-d14f6f42693d', 'X-Kubernetes-Pf-Prioritylevel-Uid': '65293b66-18ce-4abf-beb1-09155f4f882e', 'Date': 'Sat, 04 Dec 2021 23:39:31 GMT', 'Content-Length': '296'})
# HTTP response body: {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"pods is forbidden: User \"system:serviceaccount:kubeflow-user:default-editor\" cannot list resource \"pods\" in API group \"\" in the namespace \"kubeflow\"","reason":"Forbidden","details":{"kind":"pods"},"code":403}

# %% [markdown]
# ## Create a pod
